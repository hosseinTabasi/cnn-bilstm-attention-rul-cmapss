# %% [markdown]
# # C-MAPSS Exploration
#
# Author: Hossein Tabasi
#
# Quick look at FD001 trajectories, piecewise RUL, and a trained attention model.

# %%
import sys
from pathlib import Path
ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

import matplotlib.pyplot as plt
import pandas as pd
from src.data.preprocess import load_train, is_synthetic

data_dir = ROOT / 'data' / 'raw'
print('synthetic:', is_synthetic(data_dir))
df = load_train(data_dir, 'FD001')
df.groupby('unit')['RUL'].max().hist(bins=20)
plt.xlabel('Max piecewise RUL');
plt.title('FD001 engine lifetime (piecewise)');
plt.show()
df.head()
